# %%
import firebase_admin
from firebase_admin import credentials, firestore

# Initialize the Firebase Admin SDK with the service account key
cred = credentials.Certificate("../firestore-key.json")
firebase_admin.initialize_app(cred)

# Initialize Firestore client
db = firestore.client()

# List of tasks to add to the Firestore database
tasks = [
    "Pretend you're a mind reader and predict someone’s next sentence.",
    "Casually mention you've won an obscure contest.",
    "Ask someone for directions to a place that doesn't exist.",
    "Compliment someone on their shoes twice in one conversation.",
    "Drop a pen and ask someone to pick it up for you.",
    "Make up a completely random fact about a common object.",
    "Whisper every time you speak for the next 5 minutes.",
    "Convince someone you’ve lost your sense of smell.",
    "Tell a story that didn’t happen, and see if anyone notices.",
    "Bring up a random topic and act like it’s the most important subject.",
    "Start humming a random tune and see if others join.",
    "Pretend to forget someone’s name and ask them what it is again.",
    "Mention that you can hear something others can’t.",
    "Pick up something that isn’t yours and act like you lost it.",
    "Tell someone you’ve been learning a new language and say a made-up phrase.",
    "Look confused after someone says something simple.",
    "Ask someone to guess a number between 1 and 100, but never reveal the correct answer.",
    "Pretend you’re getting an important phone call and act serious.",
    "Ask someone to hold something for you, but never take it back.",
    "Tell someone a word has lost all meaning to you and repeat it multiple times.",
    "Convince someone you're afraid of an everyday object.",
    "Ask someone if they’ve ever had a paranormal experience, and act completely serious.",
    "Pretend you’ve just realized something amazing and share a mundane fact.",
    "Compliment someone on something small and keep bringing it up.",
    "Stand up, stretch, and sit back down without explanation.",
    "Tell someone you’ve always wanted to visit a country that doesn’t exist.",
    "Keep glancing at a door or window suspiciously.",
    "Ask someone if they’ve noticed the room feels different today.",
    "Pretend to forget how to use a common object.",
    "Mention an imaginary friend and ask if anyone else can see them.",
    "Apologize to someone for a ‘mistake’ you didn’t make.",
    "Convince someone that a random object is voice-activated.",
    "Repeat someone’s name often in a conversation.",
    "Tell someone you've learned how to read minds, but refuse to demonstrate.",
    "Switch the topic of conversation whenever someone asks a direct question.",
    "Pretend to be deeply interested in a random part of the room.",
    "Ask someone if they’ve ever thought about becoming a professional athlete.",
    "Act like you’ve never heard of something common, like a TV or phone.",
    "Pretend you’re confused about a simple task, like tying your shoes.",
    "Start telling a long story and stop halfway through, then change the topic.",
    "Ask someone if they believe in time travel, then act like you’ve done it.",
    "Drop something small and keep picking it up repeatedly.",
    "Use a common word incorrectly in multiple conversations.",
    "Convince someone that a random object is broken and can’t be used.",
    "Ask someone to guess your middle name and never confirm if they’re right.",
    "Act like you’re suddenly bad at counting simple numbers.",
    "Tell someone you’re working on a secret project, but give no details.",
    "Make an object ‘disappear’ by hiding it in your pocket and acting amazed.",
    "Ask someone if they can guess what you had for breakfast.",
    "Pretend you’re allergic to something harmless like air or water.",
    "Laugh randomly during a serious conversation.",
    "Mention you’ve seen someone do something amazing, but give no context.",
    "Ask someone if they’ve ever seen a UFO, then act suspicious.",
    "Pretend you don’t know the date and keep asking others for the correct day.",
    "Ask someone if they’ve ever met a famous person, then tell an imaginary story.",
    "Act like you’re deeply considering something when someone speaks.",
    "Ask someone if they’ve seen your pet (that doesn’t exist).",
    "Pretend you’ve never heard of a very common place or object.",
    "Convince someone that you’re an expert in a random, made-up subject.",
    "Pretend to misunderstand something simple and ask for an explanation.",
    "Start talking about a movie that doesn’t exist, but act like it’s famous.",
    "Ask someone to hold your phone, then pretend you lost it.",
    "Repeat the same question to multiple people until someone notices.",
    "Convince someone that a common object is incredibly rare.",
    "Ask someone to help you with something simple, then act confused.",
    "Ask someone to guess your favorite color and change it every time.",
    "Start every sentence for the next five minutes with ‘Did you know?’",
    "Ask someone if they remember something they’ve never experienced.",
    "Pretend to be an expert on something you know nothing about.",
    "Compliment someone on something imaginary, like their ‘aura.’",
    "Pretend to forget where you are and ask someone for directions.",
    "Act surprised when someone says something obvious.",
    "Pretend you’ve invented a new gadget and describe it vaguely.",
    "Ask someone if they’ve heard about a news event you’ve made up.",
    "Compliment someone on how well they did something, even if they didn’t do it.",
    "Pretend you’ve forgotten how to hold a cup properly.",
    "Ask someone if they’ve heard a strange noise, then act concerned.",
    "Tell someone you’ve just realized the meaning of life, but never explain.",
    "Repeat the same word multiple times in a conversation until someone notices.",
    "Ask someone if they’ve ever met a ghost and act serious.",
    "Convince someone that you’ve switched your dominant hand.",
    "Pretend to yawn repeatedly and see if others yawn too.",
    "Ask someone if they’ve ever visited a place that doesn’t exist.",
    "Tell someone you’ve been thinking a lot about ‘the universe,’ then say nothing else.",
    "Pretend to write a letter to someone imaginary and ask for their advice.",
    "Ask someone if they can guess your birthday and never confirm it.",
    "Talk about a book or show that doesn’t exist, and act like it’s very popular.",
    "Pretend you’re searching for something small, then give up suddenly.",
    "Tell someone you’ve just seen something amazing, but refuse to explain.",
    "Ask someone if they’ve ever had an imaginary friend, and act serious.",
    "Start talking about a hobby you don’t have, and describe it in detail.",
    "Pretend to forget how to use a door and ask for help.",
    "Convince someone that you’re secretly famous, but don’t give details.",
    "Mention you’ve been working on an important project, but give no details.",
    "Ask someone what they think of your new invention, but never show it to them.",
    "Pretend to be very interested in the weather for the next five minutes.",
    "Ask someone if they’ve ever heard of a food item you just made up.",
    "Tell someone you’ve just been to an incredible place that doesn’t exist.",
    "Pretend you’ve suddenly forgotten what year it is and keep asking others.",
    "Ask someone to guess a number between 1 and 10, but keep changing it.",
    "Convince someone that you’ve never heard of a very common thing, like a car."
]

# Reference to the Firestore 'tasks' collection
collection_ref = db.collection('tasks')

# Add each task to Firestore as a document in the 'tasks' collection
for task in tasks:
    doc_ref = collection_ref.add({
        'name': task
    })
    print(f'Task added: {task}')
# Out:
# Task added: Pretend you're a mind reader and predict someone’s next sentence.
# Task added: Casually mention you've won an obscure contest.
# Task added: Ask someone for directions to a place that doesn't exist.
# Task added: Compliment someone on their shoes twice in one conversation.
# Task added: Drop a pen and ask someone to pick it up for you.
# Task added: Make up a completely random fact about a common object.
# Task added: Whisper every time you speak for the next 5 minutes.
# Task added: Convince someone you’ve lost your sense of smell.
# Task added: Tell a story that didn’t happen, and see if anyone notices.
# Task added: Bring up a random topic and act like it’s the most important subject.
# Task added: Start humming a random tune and see if others join.
# Task added: Pretend to forget someone’s name and ask them what it is again.
# Task added: Mention that you can hear something others can’t.
# Task added: Pick up something that isn’t yours and act like you lost it.
# Task added: Tell someone you’ve been learning a new language and say a made-up phrase.
# Task added: Look confused after someone says something simple.
# Task added: Ask someone to guess a number between 1 and 100, but never reveal the correct answer.
# Task added: Pretend you’re getting an important phone call and act serious.
# Task added: Ask someone to hold something for you, but never take it back.
# Task added: Tell someone a word has lost all meaning to you and repeat it multiple times.
# Task added: Convince someone you're afraid of an everyday object.
# Task added: Ask someone if they’ve ever had a paranormal experience, and act completely serious.
# Task added: Pretend you’ve just realized something amazing and share a mundane fact.
# Task added: Compliment someone on something small and keep bringing it up.
# Task added: Stand up, stretch, and sit back down without explanation.
# Task added: Tell someone you’ve always wanted to visit a country that doesn’t exist.
# Task added: Keep glancing at a door or window suspiciously.
# Task added: Ask someone if they’ve noticed the room feels different today.
# Task added: Pretend to forget how to use a common object.
# Task added: Mention an imaginary friend and ask if anyone else can see them.
# Task added: Apologize to someone for a ‘mistake’ you didn’t make.
# Task added: Convince someone that a random object is voice-activated.
# Task added: Repeat someone’s name often in a conversation.
# Task added: Tell someone you've learned how to read minds, but refuse to demonstrate.
# Task added: Switch the topic of conversation whenever someone asks a direct question.
# Task added: Pretend to be deeply interested in a random part of the room.
# Task added: Ask someone if they’ve ever thought about becoming a professional athlete.
# Task added: Act like you’ve never heard of something common, like a TV or phone.
# Task added: Pretend you’re confused about a simple task, like tying your shoes.
# Task added: Start telling a long story and stop halfway through, then change the topic.
# Task added: Ask someone if they believe in time travel, then act like you’ve done it.
# Task added: Drop something small and keep picking it up repeatedly.
# Task added: Use a common word incorrectly in multiple conversations.
# Task added: Convince someone that a random object is broken and can’t be used.
# Task added: Ask someone to guess your middle name and never confirm if they’re right.
# Task added: Act like you’re suddenly bad at counting simple numbers.
# Task added: Tell someone you’re working on a secret project, but give no details.
# Task added: Make an object ‘disappear’ by hiding it in your pocket and acting amazed.
# Task added: Ask someone if they can guess what you had for breakfast.
# Task added: Pretend you’re allergic to something harmless like air or water.
# Task added: Laugh randomly during a serious conversation.
# Task added: Mention you’ve seen someone do something amazing, but give no context.
# Task added: Ask someone if they’ve ever seen a UFO, then act suspicious.
# Task added: Pretend you don’t know the date and keep asking others for the correct day.
# Task added: Ask someone if they’ve ever met a famous person, then tell an imaginary story.
# Task added: Act like you’re deeply considering something when someone speaks.
# Task added: Ask someone if they’ve seen your pet (that doesn’t exist).
# Task added: Pretend you’ve never heard of a very common place or object.
# Task added: Convince someone that you’re an expert in a random, made-up subject.
# Task added: Pretend to misunderstand something simple and ask for an explanation.
# Task added: Start talking about a movie that doesn’t exist, but act like it’s famous.
# Task added: Ask someone to hold your phone, then pretend you lost it.
# Task added: Repeat the same question to multiple people until someone notices.
# Task added: Convince someone that a common object is incredibly rare.
# Task added: Ask someone to help you with something simple, then act confused.
# Task added: Ask someone to guess your favorite color and change it every time.
# Task added: Start every sentence for the next five minutes with ‘Did you know?’
# Task added: Ask someone if they remember something they’ve never experienced.
# Task added: Pretend to be an expert on something you know nothing about.
# Task added: Compliment someone on something imaginary, like their ‘aura.’
# Task added: Pretend to forget where you are and ask someone for directions.
# Task added: Act surprised when someone says something obvious.
# Task added: Pretend you’ve invented a new gadget and describe it vaguely.
# Task added: Ask someone if they’ve heard about a news event you’ve made up.
# Task added: Compliment someone on how well they did something, even if they didn’t do it.
# Task added: Pretend you’ve forgotten how to hold a cup properly.
# Task added: Ask someone if they’ve heard a strange noise, then act concerned.
# Task added: Tell someone you’ve just realized the meaning of life, but never explain.
# Task added: Repeat the same word multiple times in a conversation until someone notices.
# Task added: Ask someone if they’ve ever met a ghost and act serious.
# Task added: Convince someone that you’ve switched your dominant hand.
# Task added: Pretend to yawn repeatedly and see if others yawn too.
# Task added: Ask someone if they’ve ever visited a place that doesn’t exist.
# Task added: Tell someone you’ve been thinking a lot about ‘the universe,’ then say nothing else.
# Task added: Pretend to write a letter to someone imaginary and ask for their advice.
# Task added: Ask someone if they can guess your birthday and never confirm it.
# Task added: Talk about a book or show that doesn’t exist, and act like it’s very popular.
# Task added: Pretend you’re searching for something small, then give up suddenly.
# Task added: Tell someone you’ve just seen something amazing, but refuse to explain.
# Task added: Ask someone if they’ve ever had an imaginary friend, and act serious.
# Task added: Start talking about a hobby you don’t have, and describe it in detail.
# Task added: Pretend to forget how to use a door and ask for help.
# Task added: Convince someone that you’re secretly famous, but don’t give details.
# Task added: Mention you’ve been working on an important project, but give no details.
# Task added: Ask someone what they think of your new invention, but never show it to them.
# Task added: Pretend to be very interested in the weather for the next five minutes.
# Task added: Ask someone if they’ve ever heard of a food item you just made up.
# Task added: Tell someone you’ve just been to an incredible place that doesn’t exist.
# Task added: Pretend you’ve suddenly forgotten what year it is and keep asking others.
# Task added: Ask someone to guess a number between 1 and 10, but keep changing it.
# Task added: Convince someone that you’ve never heard of a very common thing, like a car.
